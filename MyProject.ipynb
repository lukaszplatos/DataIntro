# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import CSV file
pd.read_csv('D:/CSV/Top250.csv')
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
# Set up file name
top = pd.read_csv('D:/CSV/Top250.csv')

# %%
# Use head function
top.head(50)
# Out:
#     Rank                           Restaurant  \
# 0      1                           McDonald's
# 1      2                            Starbucks
# 2      3                          Chick-fil-A
# 3      4                            Taco Bell
# 4      5                          Burger King
# 5      6                               Subway
# 6      7                              Wendy's
# 7      8                              Dunkin'
# 8      9                             Domino's
# 9     10                         Panera Bread
# 10    11                            Pizza Hut
# 11    12               Chipotle Mexican Grill
# 12    13                       Sonic Drive-In
# 13    14                                  KFC
# 14    15                         Olive Garden
# 15    16                           Applebee's
# 16    17                        Panda Express
# 17    18                               Arby's
# 18    19            Popeyes Louisiana Kitchen
# ...

# %%
# Use info function
top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              250 non-null    int64
#  1   Restaurant        250 non-null    object
#  2   Content           33 non-null     object
#  3   Sales             250 non-null    int64
#  4   YOY_Sales         250 non-null    object
#  5   Units             250 non-null    int64
#  6   YOY_Units         250 non-null    object
#  7   Headquarters      52 non-null     object
#  8   Segment_Category  250 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 11.8+ KB

# %%
top.describe()
# Out:
#              Rank        Sales         Units
# count  250.000000    250.00000    250.000000
# mean   125.500000   1242.74000    850.076000
# std     72.312977   3365.22882   2296.151659
# min      1.000000    126.00000     13.000000
# 25%     63.250000    181.00000     85.000000
# 50%    125.500000    330.00000    207.000000
# 75%    187.750000    724.75000    555.250000
# max    250.000000  40412.00000  23801.000000

# %%
# Set new index
top.set_index('Rank')
# Out:
#                Restaurant                                            Content  \
# Rank
# 1              McDonald's                                                NaN
# 2               Starbucks                                                NaN
# 3             Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 4               Taco Bell                                                NaN
# 5             Burger King                                                NaN
# ...                   ...                                                ...
# 246       Rainforest Cafe                                                NaN
# 247                   PDQ                                                NaN
# 248         Lupe Tortilla                                                NaN
# 249   Cook-Out Restaurant                                                NaN
# 250              Jollibee                                                NaN
#
# ...

# %%
top.set_index('Rank'). head(20)
# Out:
#                      Restaurant  \
# Rank
# 1                    McDonald's
# 2                     Starbucks
# 3                   Chick-fil-A
# 4                     Taco Bell
# 5                   Burger King
# 6                        Subway
# 7                       Wendy's
# 8                       Dunkin'
# 9                      Domino's
# 10                 Panera Bread
# 11                    Pizza Hut
# 12       Chipotle Mexican Grill
# 13               Sonic Drive-In
# 14                          KFC
# 15                 Olive Garden
# 16                   Applebee's
# 17                Panda Express
# 18                       Arby's
# 19    Popeyes Louisiana Kitchen
# 20               Little Caesars
#
#                                                 Content  Sales YOY_Sales  \
# Rank
# 1                                                   NaN  40412      4.9%
# 2                                                   NaN  21380      8.6%
# ...

# %%
# Sorting by columns
top[['Restaurant', 'Sales', 'YOY_Sales']]
# Out:
#               Restaurant  Sales YOY_Sales
# 0             McDonald's  40412      4.9%
# 1              Starbucks  21380      8.6%
# 2            Chick-fil-A  11320     13.0%
# 3              Taco Bell  11293      9.0%
# 4            Burger King  10204      2.7%
# ..                   ...    ...       ...
# 245      Rainforest Cafe    129    -10.4%
# 246                  PDQ    127     -5.5%
# 247        Lupe Tortilla    127     12.1%
# 248  Cook-Out Restaurant    126     10.1%
# 249             Jollibee    126     15.2%
#
# [250 rows x 3 columns]

# %%
top[['Restaurant', 'Sales', 'YOY_Sales']]. head(20)
# Out:
#                    Restaurant  Sales YOY_Sales
# 0                  McDonald's  40412      4.9%
# 1                   Starbucks  21380      8.6%
# 2                 Chick-fil-A  11320     13.0%
# 3                   Taco Bell  11293      9.0%
# 4                 Burger King  10204      2.7%
# 5                      Subway  10200     -2.0%
# 6                     Wendy's   9762      4.2%
# 7                     Dunkin'   9228      5.0%
# 8                    Domino's   7044      6.9%
# 9                Panera Bread   5890      4.0%
# 10                  Pizza Hut   5558      0.6%
# 11     Chipotle Mexican Grill   5509     14.8%
# 12             Sonic Drive-In   4687      4.6%
# 13                        KFC   4546      2.5%
# 14               Olive Garden   4287      5.0%
# 15                 Applebee's   4085     -3.0%
# 16              Panda Express   3946     12.0%
# 17                     Arby's   3884      1.9%
# 18  Popeyes Louisiana Kitchen   3812     18.3%
# ...

# %%
# Dropping duplicates
top.drop_duplicates(subset=['Restaurant'], inplace=True)
top
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
# Slicing using ilock
top.iloc[0:5]
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412      4.9%  13846     -0.5%          NaN       Quick Service & Burger
# 1  21380      8.6%  15049      3.0%          NaN  Quick Service & Coffee Cafe
# 2  11320     13.0%   2470      5.0%          NaN      Quick Service & Chicken
# 3  11293      9.0%   6766      2.7%          NaN      Quick Service & Mexican
# 4  10204      2.7%   7346      0.2%          NaN       Quick Service & Burger

# %%
top2 = top.iloc[0:5, 1:6]
top2
# Out:
#     Restaurant                                            Content  Sales  \
# 0   McDonald's                                                NaN  40412
# 1    Starbucks                                                NaN  21380
# 2  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...  11320
# 3    Taco Bell                                                NaN  11293
# 4  Burger King                                                NaN  10204
#
#   YOY_Sales  Units
# 0      4.9%  13846
# 1      8.6%  15049
# 2     13.0%   2470
# 3      9.0%   6766
# 4      2.7%   7346

# %%
top1 = top.iloc[0:20, 0:6]. set_index('Rank')
top1
# Out:
#                      Restaurant  \
# Rank
# 1                    McDonald's
# 2                     Starbucks
# 3                   Chick-fil-A
# 4                     Taco Bell
# 5                   Burger King
# 6                        Subway
# 7                       Wendy's
# 8                       Dunkin'
# 9                      Domino's
# 10                 Panera Bread
# 11                    Pizza Hut
# 12       Chipotle Mexican Grill
# 13               Sonic Drive-In
# 14                          KFC
# 15                 Olive Garden
# 16                   Applebee's
# 17                Panda Express
# 18                       Arby's
# 19    Popeyes Louisiana Kitchen
# 20               Little Caesars
#
#                                                 Content  Sales YOY_Sales  \
# Rank
# 1                                                   NaN  40412      4.9%
# 2                                                   NaN  21380      8.6%
# ...

# %%
# Creating first plot
top1['Sales'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Rank'>

# %%
# Checking for missing values
top1.isnull().sum()
# Out:
# Restaurant     0
# Content       13
# Sales          0
# YOY_Sales      0
# Units          0
# dtype: int64

# %%
top2 = top1[~top1['Content'].isnull()]
top2
# Out:
#           Restaurant                                            Content  \
# Rank
# 3        Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 8            Dunkin'  Dunkin' dropped "Donuts" from its name and rep...
# 11         Pizza Hut  The chain moved to replace underperforming din...
# 13    Sonic Drive-In  The drive-in chain grew same-store sales for t...
# 15      Olive Garden  Olive Garden became the nation's largest casua...
# 17     Panda Express  Panda Express has quietly established itself a...
# 20    Little Caesars  The third-largest pizza chain's self-service, ...
#
#       Sales YOY_Sales  Units
# Rank
# 3     11320     13.0%   2470
# 8      9228      5.0%   9630
# 11     5558      0.6%   7306
# 13     4687      4.6%   3526
# 15     4287      5.0%    866
# 17     3946     12.0%   2209
# 20     3811      2.7%   4237

# %%
# Grouping data by Category with sum
top_grouped = top.groupby('Segment_Category').sum()
top_grouped
# Out:
#                                  Rank  Sales  Units
# Segment_Category
# Asian                             597    608    140
# Asian/Noodle                      521    681    565
# BBQ                              1304   1472   1140
# Bakery Cafe                      1423   1717   1094
# Burger                           1765   2187   2427
# Casual Dining & Asian              52    917    221
# Casual Dining & Italian/Pizza     250   6022   1477
# Casual Dining & Seafood           106   3077    876
# Casual Dining & Sports Bar        176   4973   1645
# Casual Dining & Steak             184   8014   2011
# Casual Dining & Varied Menu       410  15686   4967
# Chicken                          1441   1318    805
# Coffee Cafe                       726    925   1409
# Ethnic                            220    149     93
# Family Casual                     721    807    347
# Family Dining & Family Style      353  11677   7047
# Family Style                     1698   2292   1508
# ...

# %%
# Grouping data by Category with average
top_grouped1 = top.groupby('Segment_Category').mean()
top_grouped1
# Out:
#                                        Rank        Sales        Units
# Segment_Category
# Asian                            199.000000   202.666667    46.666667
# Asian/Noodle                     173.666667   227.000000   188.333333
# BBQ                              186.285714   210.285714   162.857143
# Bakery Cafe                      177.875000   214.625000   136.750000
# Burger                           176.500000   218.700000   242.700000
# Casual Dining & Asian             52.000000   917.000000   221.000000
# Casual Dining & Italian/Pizza     62.500000  1505.500000   369.250000
# Casual Dining & Seafood           53.000000  1538.500000   438.000000
# Casual Dining & Sports Bar        58.666667  1657.666667   548.333333
# Casual Dining & Steak             46.000000  2003.500000   502.750000
# Casual Dining & Varied Menu       45.555556  1742.888889   551.888889
# Chicken                          205.857143   188.285714   115.000000
# ...

# %%
top_grouped2 = top.groupby('Segment_Category').count()
top_grouped2
# Out:
#                                  Rank  Restaurant  Content  Sales  YOY_Sales  \
# Segment_Category
# Asian                               3           3        0      3          3
# Asian/Noodle                        3           3        0      3          3
# BBQ                                 7           7        1      7          7
# Bakery Cafe                         8           8        2      8          8
# Burger                             10          10        1     10         10
# Casual Dining & Asian               1           1        0      1          1
# Casual Dining & Italian/Pizza       4           4        1      4          4
# Casual Dining & Seafood             2           2        0      2          2
# Casual Dining & Sports Bar          3           3        0      3          3
# Casual Dining & Steak               4           4        0      4          4
# Casual Dining & Varied Menu         9           9        2      9          9
# ...

# %%
# Grouping by restaurant served burgers
burger = top['Segment_Category']. groupby(top['Burger']).count()
burger
# Out:
# Burger
# NO OK    223
# OK        27
# Name: Segment_Category, dtype: int64

# %%
# Grouping by restaurant served Mexican food
mex = top['Segment_Category']. groupby(top['Mexican']).count()
mex
# Out:
# Mexican
# NO OK    231
# OK        19
# Name: Segment_Category, dtype: int64

# %%
# Looping
for lab, row in top.iterrows():
    if "burger" in str(row['Segment_Category']).lower():
        top.loc[lab, 'Burger'] = 'OK'
    else:
        top.loc[lab, 'Burger'] = 'NO OK'
top.head(20)
# Out:
#     Rank                 Restaurant  \
# 0      1                 McDonald's
# 1      2                  Starbucks
# 2      3                Chick-fil-A
# 3      4                  Taco Bell
# 4      5                Burger King
# 5      6                     Subway
# 6      7                    Wendy's
# 7      8                    Dunkin'
# 8      9                   Domino's
# 9     10               Panera Bread
# 10    11                  Pizza Hut
# 11    12     Chipotle Mexican Grill
# 12    13             Sonic Drive-In
# 13    14                        KFC
# 14    15               Olive Garden
# 15    16                 Applebee's
# 16    17              Panda Express
# 17    18                     Arby's
# 18    19  Popeyes Louisiana Kitchen
# 19    20             Little Caesars
#
#                                               Content  Sales YOY_Sales  Units  \
# 0                                                 NaN  40412      4.9%  13846
# ...

# %%
for lab, row in top.iterrows():
    if "mexican" in str(row['Segment_Category']).lower():
        top.loc[lab, 'Mexican'] = 'OK'
    else:
        top.loc[lab, 'Mexican'] = 'NO OK'
top.head(20)
# Out:
#     Rank                 Restaurant  \
# 0      1                 McDonald's
# 1      2                  Starbucks
# 2      3                Chick-fil-A
# 3      4                  Taco Bell
# 4      5                Burger King
# 5      6                     Subway
# 6      7                    Wendy's
# 7      8                    Dunkin'
# 8      9                   Domino's
# 9     10               Panera Bread
# 10    11                  Pizza Hut
# 11    12     Chipotle Mexican Grill
# 12    13             Sonic Drive-In
# 13    14                        KFC
# 14    15               Olive Garden
# 15    16                 Applebee's
# 16    17              Panda Express
# 17    18                     Arby's
# 18    19  Popeyes Louisiana Kitchen
# 19    20             Little Caesars
#
#                                               Content  Sales YOY_Sales  Units  \
# 0                                                 NaN  40412      4.9%  13846
# ...

# %%
# Visualization
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(top1["Restaurant"], top1['Sales'], color="b", edgecolor='black')
ax.set_xticklabels(top1['Restaurant'], rotation=70, fontsize=10)
ax.set_xlabel('Restaurant')
ax.set_ylabel('Sales')
ax.set_title('Sales in bln in 2020')
# Out:
# <ipython-input-26-10d6a81e61a7>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(top1['Restaurant'], rotation=70, fontsize=10)
# Text(0.5, 1.0, 'Sales in bln in 2020')

# %%
fig, ax = plt.subplots(figsize=(13,7))
ax.bar(top1["Restaurant"], top1['Units'], color="g", edgecolor='black')
ax.set_xticklabels(top1['Restaurant'], rotation=70, fontsize=10)
ax.set_xlabel('Restaurant')
ax.set_ylabel('Units')
ax.set_title('How many meals were sold in 2020')
# Out:
# <ipython-input-34-61a91965c38c>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(top1['Restaurant'], rotation=70, fontsize=10)
# Text(0.5, 1.0, 'How many meals were sold in 2020')

# %%
# Merging data from two files
top4 = pd.read_csv('D:/CSV/Top250.csv')
top
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
ind = pd.read_csv('D:/CSV/Independence100.csv')
ind
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
# Merging by all columns
top.merge(ind, how="outer")
# Out:
#      Rank              Restaurant  \
# 0       1              McDonald's
# 1       2               Starbucks
# 2       3             Chick-fil-A
# 3       4               Taco Bell
# 4       5             Burger King
# ..    ...                     ...
# 345    96    George's at the Cove
# 346    97               Le Coucou
# 347    98                 Mi Vida
# 348    99                  Upland
# 349   100  Virgil's Real Barbecue
#
#                                                Content       Sales YOY_Sales  \
# 0                                                  NaN     40412.0      4.9%
# 1                                                  NaN     21380.0      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...     11320.0     13.0%
# 3                                                  NaN     11293.0      9.0%
# 4                                                  NaN     10204.0      2.7%
# ..                                                 ...         ...       ...
# ...

# %%
top.merge(ind, on="Sales", how="outer")
# Out:
#      Rank_x Restaurant_x                                            Content  \
# 0       1.0   McDonald's                                                NaN
# 1       2.0    Starbucks                                                NaN
# 2       3.0  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3       4.0    Taco Bell                                                NaN
# 4       5.0  Burger King                                                NaN
# ..      ...          ...                                                ...
# 345     NaN          NaN                                                NaN
# 346     NaN          NaN                                                NaN
# 347     NaN          NaN                                                NaN
# 348     NaN          NaN                                                NaN
# 349     NaN          NaN                                                NaN
#
# ...
