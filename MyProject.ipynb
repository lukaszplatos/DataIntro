# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import csv file
pd.read_csv('D:/CSV/Top250.csv')
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# 246                                                NaN    127     -5.5%
# 247                                                NaN    127     12.1%
# 248                                                NaN    126     10.1%
# 249                                                NaN    126     15.2%
#
#      Units YOY_Units Headquarters             Segment_Category
# 0    13846     -0.5%          NaN       Quick Service & Burger
# 1    15049      3.0%          NaN  Quick Service & Coffee Cafe
# 2     2470      5.0%          NaN      Quick Service & Chicken
# 3     6766      2.7%          NaN      Quick Service & Mexican
# 4     7346      0.2%          NaN       Quick Service & Burger
# ..     ...       ...          ...                          ...
# 245     18     -5.3%          NaN                  Varied Menu
# 246     56    -11.1%          NaN                      Chicken
# 247     25      8.7%          NaN                      Mexican
# 248    270      7.1%          NaN                       Burger
# 249     40     11.1%          NaN                      Chicken
#
# [250 rows x 9 columns]

# %%
# Set up file name
top = pd.read_csv('D:/CSV/Top250.csv')

# %%
top.head(50)
# Out:
#     Rank                           Restaurant  \
# 0      1                           McDonald's
# 1      2                            Starbucks
# 2      3                          Chick-fil-A
# 3      4                            Taco Bell
# 4      5                          Burger King
# 5      6                               Subway
# 6      7                              Wendy's
# 7      8                              Dunkin'
# 8      9                             Domino's
# 9     10                         Panera Bread
# 10    11                            Pizza Hut
# 11    12               Chipotle Mexican Grill
# 12    13                       Sonic Drive-In
# 13    14                                  KFC
# 14    15                         Olive Garden
# 15    16                           Applebee's
# 16    17                        Panda Express
# 17    18                               Arby's
# 18    19            Popeyes Louisiana Kitchen
# 19    20                       Little Caesars
# 20    21                          Dairy Queen
# 21    22                   Buffalo Wild Wings
# 22    23                  Chili's Grill & Bar
# 23    24                      Jack in the Box
# 24    25                                 IHOP
# 25    26                      Texas Roadhouse
# 26    27                              Denny's
# 27    28                          Papa John's
# 28    29                   Outback Steakhouse
# 29    30                          Whataburger
# 30    31                          Red Lobster
# 31    32                       Cracker Barrel
# 32    33               The Cheesecake Factory
# 33    34      Jimmy John's Gourmet Sandwiches
# 34    35                             Hardee's
# 35    36                              Zaxby's
# 36    37                  LongHorn Steakhouse
# 37    38                             Culver's
# 38    39                        Golden Corral
# 39    40          Five Guys Burgers and Fries
# 40    41  Red Robin Gourmet Burgers and Brews
# 41    42       Raising Cane's Chicken Fingers
# 42    43                           Carl's Jr.
# 43    44                             Wingstop
# 44    45                         Waffle House
# 45    46                   Jersey Mike's Subs
# 46    47                           Bojangles'
# 47    48          BJ's Restaurant & Brewhouse
# 48    49                          TGI Fridays
# 49    50                      In-N-Out Burger
#
#                                               Content  Sales YOY_Sales  Units  \
# 0                                                 NaN  40412      4.9%  13846
# 1                                                 NaN  21380      8.6%  15049
# 2   While Popeyes got a lot of the chicken buzz in...  11320     13.0%   2470
# 3                                                 NaN  11293      9.0%   6766
# 4                                                 NaN  10204      2.7%   7346
# 5                                                 NaN  10200     -2.0%  23801
# 6                                                 NaN   9762      4.2%   5852
# 7   Dunkin' dropped "Donuts" from its name and rep...   9228      5.0%   9630
# 8                                                 NaN   7044      6.9%   6126
# 9                                                 NaN   5890      4.0%   2160
# 10  The chain moved to replace underperforming din...   5558      0.6%   7306
# 11                                                NaN   5509     14.8%   2584
# 12  The drive-in chain grew same-store sales for t...   4687      4.6%   3526
# 13                                                NaN   4546      2.5%   4065
# 14  Olive Garden became the nation's largest casua...   4287      5.0%    866
# 15                                                NaN   4085     -3.0%   1665
# 16  Panda Express has quietly established itself a...   3946     12.0%   2209
# 17                                                NaN   3884      1.9%   3359
# 18                                                NaN   3812     18.3%   2476
# 19  The third-largest pizza chain's self-service, ...   3811      2.7%   4237
# 20                                                NaN   3760      2.9%   4381
# 21                                                NaN   3669     -0.1%   1206
# 22                                                NaN   3563      2.2%   1242
# 23                                                NaN   3504      1.1%   2243
# 24                                                NaN   3266      2.0%   1710
# 25                                                NaN   3016     11.0%    553
# 26                                                NaN   2691      1.1%   1558
# 27                                                NaN   2638     -2.7%   3142
# 28                                                NaN   2635      0.9%    724
# 29                                                NaN   2556      5.8%    830
# 30                                                NaN   2490      1.6%    679
# 31  Cracker Barrel made the most surprising deal o...   2482      1.8%    660
# 32                                                NaN   2180      2.5%    206
# 33                                                NaN   2105     -1.6%   2787
# 34                                                NaN   2020     -4.0%   1820
# 35                                                NaN   1886      6.0%    910
# 36                                                NaN   1867      6.3%    530
# 37  One of the country's fastest-growing chains ov...   1795     13.9%    732
# 38                                                NaN   1746      0.8%    483
# 39                                                NaN   1661      7.4%   1368
# 40  A tumultuous year for the burger chain include...   1548     -0.3%    556
# 41                                                NaN   1466     23.8%    457
# 42                                                NaN   1423     -2.5%   1095
# 43  2019 marked Wingstop's 16th consecutive year o...   1363     19.0%   1231
# 44                                       Waffle House   1344      3.4%   1959
# 45                                                NaN   1340     16.7%   1667
# 46                                                NaN   1331      2.7%    746
# 47  BJ's Restaurants' bullish approach to off-prem...   1161      4.0%    208
# 48                                                NaN   1085     -8.5%    385
# 49                                                NaN    957      4.6%    351
#
#    YOY_Units Headquarters                 Segment_Category
# 0      -0.5%          NaN           Quick Service & Burger
# 1       3.0%          NaN      Quick Service & Coffee Cafe
# 2       5.0%          NaN          Quick Service & Chicken
# 3       2.7%          NaN          Quick Service & Mexican
# 4       0.2%          NaN           Quick Service & Burger
# 5      -4.0%          NaN         Quick Service & Sandwich
# 6       0.7%          NaN           Quick Service & Burger
# 7       2.2%          NaN      Quick Service & Coffee Cafe
# 8       4.3%          NaN            Quick Service & Pizza
# 9       3.2%          NaN        Fast Casual & Bakery Cafe
# 10     -2.4%          NaN            Quick Service & Pizza
# 11      5.3%          NaN            Fast Casual & Mexican
# 12     -2.1%          NaN           Quick Service & Burger
# 13     -0.2%          NaN          Quick Service & Chicken
# 14      1.3%          NaN    Casual Dining & Italian/Pizza
# 15     -1.7%          NaN      Casual Dining & Varied Menu
# 16      4.9%          NaN       Fast Casual & Asian/Noodle
# 17      0.9%          NaN         Quick Service & Sandwich
# 18      5.5%          NaN          Quick Service & Chicken
# 19     -0.6%          NaN            Quick Service & Pizza
# 20     -0.6%          NaN  Quick Service & Frozen Desserts
# 21     -0.2%          NaN       Casual Dining & Sports Bar
# 22     -0.7%          NaN      Casual Dining & Varied Menu
# 23      0.3%          NaN           Quick Service & Burger
# 24      0.3%          NaN     Family Dining & Family Style
# 25      3.8%          NaN            Casual Dining & Steak
# 26     -1.5%          NaN     Family Dining & Family Style
# 27     -1.8%          NaN            Quick Service & Pizza
# 28     -1.2%          NaN            Casual Dining & Steak
# 29      0.6%          NaN           Quick Service & Burger
# 30      0.1%          NaN          Casual Dining & Seafood
# 31      0.8%          NaN     Family Dining & Family Style
# 32      2.5%          NaN      Casual Dining & Varied Menu
# 33     -0.5%          NaN           Fast Casual & Sandwich
# 34     -1.4%          NaN           Quick Service & Burger
# 35      1.3%          NaN            Fast Casual & Chicken
# 36      1.9%          NaN            Casual Dining & Steak
# 37      6.7%          NaN           Quick Service & Burger
# 38     -1.2%          NaN    Quick Service & Family Casual
# 39      0.7%          NaN             Fast Casual & Burger
# 40     -3.0%          NaN      Casual Dining & Varied Menu
# 41     14.3%          NaN            Fast Casual & Chicken
# 42     -2.3%          NaN           Quick Service & Burger
# 43      9.5%          NaN            Fast Casual & Chicken
# 44      1.2%          NaN     Family Dining & Family Style
# 45     11.6%          NaN           Fast Casual & Sandwich
# 46     -1.3%          NaN          Quick Service & Chicken
# 47      3.0%          NaN      Casual Dining & Varied Menu
# 48     -7.9%          NaN      Casual Dining & Varied Menu
# 49      3.5%          NaN           Quick Service & Burger

# %%
top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              250 non-null    int64
#  1   Restaurant        250 non-null    object
#  2   Content           33 non-null     object
#  3   Sales             250 non-null    int64
#  4   YOY_Sales         250 non-null    object
#  5   Units             250 non-null    int64
#  6   YOY_Units         250 non-null    object
#  7   Headquarters      52 non-null     object
#  8   Segment_Category  250 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 11.8+ KB

# %%
top.describe()
# Out:
#              Rank        Sales         Units
# count  250.000000    250.00000    250.000000
# mean   125.500000   1242.74000    850.076000
# std     72.312977   3365.22882   2296.151659
# min      1.000000    126.00000     13.000000
# 25%     63.250000    181.00000     85.000000
# 50%    125.500000    330.00000    207.000000
# 75%    187.750000    724.75000    555.250000
# max    250.000000  40412.00000  23801.000000

# %%
top.set_index('Rank')
# Out:
#                Restaurant                                            Content  \
# Rank
# 1              McDonald's                                                NaN
# 2               Starbucks                                                NaN
# 3             Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 4               Taco Bell                                                NaN
# 5             Burger King                                                NaN
# ...                   ...                                                ...
# 246       Rainforest Cafe                                                NaN
# 247                   PDQ                                                NaN
# 248         Lupe Tortilla                                                NaN
# 249   Cook-Out Restaurant                                                NaN
# 250              Jollibee                                                NaN
#
#       Sales YOY_Sales  Units YOY_Units Headquarters  \
# Rank
# 1     40412      4.9%  13846     -0.5%          NaN
# 2     21380      8.6%  15049      3.0%          NaN
# 3     11320     13.0%   2470      5.0%          NaN
# 4     11293      9.0%   6766      2.7%          NaN
# 5     10204      2.7%   7346      0.2%          NaN
# ...     ...       ...    ...       ...          ...
# 246     129    -10.4%     18     -5.3%          NaN
# 247     127     -5.5%     56    -11.1%          NaN
# 248     127     12.1%     25      8.7%          NaN
# 249     126     10.1%    270      7.1%          NaN
# 250     126     15.2%     40     11.1%          NaN
#
#                  Segment_Category
# Rank
# 1          Quick Service & Burger
# 2     Quick Service & Coffee Cafe
# 3         Quick Service & Chicken
# 4         Quick Service & Mexican
# 5          Quick Service & Burger
# ...                           ...
# 246                   Varied Menu
# 247                       Chicken
# 248                       Mexican
# 249                        Burger
# 250                       Chicken
#
# [250 rows x 8 columns]

# %%
top.set_index('Rank'). head(20)
# Out:
#                      Restaurant  \
# Rank
# 1                    McDonald's
# 2                     Starbucks
# 3                   Chick-fil-A
# 4                     Taco Bell
# 5                   Burger King
# 6                        Subway
# 7                       Wendy's
# 8                       Dunkin'
# 9                      Domino's
# 10                 Panera Bread
# 11                    Pizza Hut
# 12       Chipotle Mexican Grill
# 13               Sonic Drive-In
# 14                          KFC
# 15                 Olive Garden
# 16                   Applebee's
# 17                Panda Express
# 18                       Arby's
# 19    Popeyes Louisiana Kitchen
# 20               Little Caesars
#
#                                                 Content  Sales YOY_Sales  \
# Rank
# 1                                                   NaN  40412      4.9%
# 2                                                   NaN  21380      8.6%
# 3     While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 4                                                   NaN  11293      9.0%
# 5                                                   NaN  10204      2.7%
# 6                                                   NaN  10200     -2.0%
# 7                                                   NaN   9762      4.2%
# 8     Dunkin' dropped "Donuts" from its name and rep...   9228      5.0%
# 9                                                   NaN   7044      6.9%
# 10                                                  NaN   5890      4.0%
# 11    The chain moved to replace underperforming din...   5558      0.6%
# 12                                                  NaN   5509     14.8%
# 13    The drive-in chain grew same-store sales for t...   4687      4.6%
# 14                                                  NaN   4546      2.5%
# 15    Olive Garden became the nation's largest casua...   4287      5.0%
# 16                                                  NaN   4085     -3.0%
# 17    Panda Express has quietly established itself a...   3946     12.0%
# 18                                                  NaN   3884      1.9%
# 19                                                  NaN   3812     18.3%
# 20    The third-largest pizza chain's self-service, ...   3811      2.7%
#
#       Units YOY_Units Headquarters               Segment_Category
# Rank
# 1     13846     -0.5%          NaN         Quick Service & Burger
# 2     15049      3.0%          NaN    Quick Service & Coffee Cafe
# 3      2470      5.0%          NaN        Quick Service & Chicken
# 4      6766      2.7%          NaN        Quick Service & Mexican
# 5      7346      0.2%          NaN         Quick Service & Burger
# 6     23801     -4.0%          NaN       Quick Service & Sandwich
# 7      5852      0.7%          NaN         Quick Service & Burger
# 8      9630      2.2%          NaN    Quick Service & Coffee Cafe
# 9      6126      4.3%          NaN          Quick Service & Pizza
# 10     2160      3.2%          NaN      Fast Casual & Bakery Cafe
# 11     7306     -2.4%          NaN          Quick Service & Pizza
# 12     2584      5.3%          NaN          Fast Casual & Mexican
# 13     3526     -2.1%          NaN         Quick Service & Burger
# 14     4065     -0.2%          NaN        Quick Service & Chicken
# 15      866      1.3%          NaN  Casual Dining & Italian/Pizza
# 16     1665     -1.7%          NaN    Casual Dining & Varied Menu
# 17     2209      4.9%          NaN     Fast Casual & Asian/Noodle
# 18     3359      0.9%          NaN       Quick Service & Sandwich
# 19     2476      5.5%          NaN        Quick Service & Chicken
# 20     4237     -0.6%          NaN          Quick Service & Pizza

# %%
top[['Restaurant', 'Sales', 'YOY_Sales']]
# Out:
#               Restaurant  Sales YOY_Sales
# 0             McDonald's  40412      4.9%
# 1              Starbucks  21380      8.6%
# 2            Chick-fil-A  11320     13.0%
# 3              Taco Bell  11293      9.0%
# 4            Burger King  10204      2.7%
# ..                   ...    ...       ...
# 245      Rainforest Cafe    129    -10.4%
# 246                  PDQ    127     -5.5%
# 247        Lupe Tortilla    127     12.1%
# 248  Cook-Out Restaurant    126     10.1%
# 249             Jollibee    126     15.2%
#
# [250 rows x 3 columns]

# %%
top[['Restaurant', 'Sales', 'YOY_Sales']]. head(20)
# Out:
#                    Restaurant  Sales YOY_Sales
# 0                  McDonald's  40412      4.9%
# 1                   Starbucks  21380      8.6%
# 2                 Chick-fil-A  11320     13.0%
# 3                   Taco Bell  11293      9.0%
# 4                 Burger King  10204      2.7%
# 5                      Subway  10200     -2.0%
# 6                     Wendy's   9762      4.2%
# 7                     Dunkin'   9228      5.0%
# 8                    Domino's   7044      6.9%
# 9                Panera Bread   5890      4.0%
# 10                  Pizza Hut   5558      0.6%
# 11     Chipotle Mexican Grill   5509     14.8%
# 12             Sonic Drive-In   4687      4.6%
# 13                        KFC   4546      2.5%
# 14               Olive Garden   4287      5.0%
# 15                 Applebee's   4085     -3.0%
# 16              Panda Express   3946     12.0%
# 17                     Arby's   3884      1.9%
# 18  Popeyes Louisiana Kitchen   3812     18.3%
# 19             Little Caesars   3811      2.7%

# %%
# Slicing using ilock
top.iloc[0:5]
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412      4.9%  13846     -0.5%          NaN       Quick Service & Burger
# 1  21380      8.6%  15049      3.0%          NaN  Quick Service & Coffee Cafe
# 2  11320     13.0%   2470      5.0%          NaN      Quick Service & Chicken
# 3  11293      9.0%   6766      2.7%          NaN      Quick Service & Mexican
# 4  10204      2.7%   7346      0.2%          NaN       Quick Service & Burger

# %%
top.iloc[0:5, 1:6]
# Out:
#     Restaurant                                            Content  Sales  \
# 0   McDonald's                                                NaN  40412
# 1    Starbucks                                                NaN  21380
# 2  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...  11320
# 3    Taco Bell                                                NaN  11293
# 4  Burger King                                                NaN  10204
#
#   YOY_Sales  Units
# 0      4.9%  13846
# 1      8.6%  15049
# 2     13.0%   2470
# 3      9.0%   6766
# 4      2.7%   7346

# %%
top1 = top.iloc[0:20, 0:6]. set_index('Restaurant')
top1
# Out:
#                            Rank  \
# Restaurant
# McDonald's                    1
# Starbucks                     2
# Chick-fil-A                   3
# Taco Bell                     4
# Burger King                   5
# Subway                        6
# Wendy's                       7
# Dunkin'                       8
# Domino's                      9
# Panera Bread                 10
# Pizza Hut                    11
# Chipotle Mexican Grill       12
# Sonic Drive-In               13
# KFC                          14
# Olive Garden                 15
# Applebee's                   16
# Panda Express                17
# Arby's                       18
# Popeyes Louisiana Kitchen    19
# Little Caesars               20
#
#                                                                      Content  \
# Restaurant
# McDonald's                                                               NaN
# Starbucks                                                                NaN
# Chick-fil-A                While Popeyes got a lot of the chicken buzz in...
# Taco Bell                                                                NaN
# Burger King                                                              NaN
# Subway                                                                   NaN
# Wendy's                                                                  NaN
# Dunkin'                    Dunkin' dropped "Donuts" from its name and rep...
# Domino's                                                                 NaN
# Panera Bread                                                             NaN
# Pizza Hut                  The chain moved to replace underperforming din...
# Chipotle Mexican Grill                                                   NaN
# Sonic Drive-In             The drive-in chain grew same-store sales for t...
# KFC                                                                      NaN
# Olive Garden               Olive Garden became the nation's largest casua...
# Applebee's                                                               NaN
# Panda Express              Panda Express has quietly established itself a...
# Arby's                                                                   NaN
# Popeyes Louisiana Kitchen                                                NaN
# Little Caesars             The third-largest pizza chain's self-service, ...
#
#                            Sales YOY_Sales  Units
# Restaurant
# McDonald's                 40412      4.9%  13846
# Starbucks                  21380      8.6%  15049
# Chick-fil-A                11320     13.0%   2470
# Taco Bell                  11293      9.0%   6766
# Burger King                10204      2.7%   7346
# Subway                     10200     -2.0%  23801
# Wendy's                     9762      4.2%   5852
# Dunkin'                     9228      5.0%   9630
# Domino's                    7044      6.9%   6126
# Panera Bread                5890      4.0%   2160
# Pizza Hut                   5558      0.6%   7306
# Chipotle Mexican Grill      5509     14.8%   2584
# Sonic Drive-In              4687      4.6%   3526
# KFC                         4546      2.5%   4065
# Olive Garden                4287      5.0%    866
# Applebee's                  4085     -3.0%   1665
# Panda Express               3946     12.0%   2209
# Arby's                      3884      1.9%   3359
# Popeyes Louisiana Kitchen   3812     18.3%   2476
# Little Caesars              3811      2.7%   4237

# %%
top1['Sales'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Restaurant'>

# %%
# Dropping duplicates
top1.drop_duplicates()
# Out:
#                            Rank  \
# Restaurant
# McDonald's                    1
# Starbucks                     2
# Chick-fil-A                   3
# Taco Bell                     4
# Burger King                   5
# Subway                        6
# Wendy's                       7
# Dunkin'                       8
# Domino's                      9
# Panera Bread                 10
# Pizza Hut                    11
# Chipotle Mexican Grill       12
# Sonic Drive-In               13
# KFC                          14
# Olive Garden                 15
# Applebee's                   16
# Panda Express                17
# Arby's                       18
# Popeyes Louisiana Kitchen    19
# Little Caesars               20
#
#                                                                      Content  \
# Restaurant
# McDonald's                                                               NaN
# Starbucks                                                                NaN
# Chick-fil-A                While Popeyes got a lot of the chicken buzz in...
# Taco Bell                                                                NaN
# Burger King                                                              NaN
# Subway                                                                   NaN
# Wendy's                                                                  NaN
# Dunkin'                    Dunkin' dropped "Donuts" from its name and rep...
# Domino's                                                                 NaN
# Panera Bread                                                             NaN
# Pizza Hut                  The chain moved to replace underperforming din...
# Chipotle Mexican Grill                                                   NaN
# Sonic Drive-In             The drive-in chain grew same-store sales for t...
# KFC                                                                      NaN
# Olive Garden               Olive Garden became the nation's largest casua...
# Applebee's                                                               NaN
# Panda Express              Panda Express has quietly established itself a...
# Arby's                                                                   NaN
# Popeyes Louisiana Kitchen                                                NaN
# Little Caesars             The third-largest pizza chain's self-service, ...
#
#                            Sales YOY_Sales  Units
# Restaurant
# McDonald's                 40412      4.9%  13846
# Starbucks                  21380      8.6%  15049
# Chick-fil-A                11320     13.0%   2470
# Taco Bell                  11293      9.0%   6766
# Burger King                10204      2.7%   7346
# Subway                     10200     -2.0%  23801
# Wendy's                     9762      4.2%   5852
# Dunkin'                     9228      5.0%   9630
# Domino's                    7044      6.9%   6126
# Panera Bread                5890      4.0%   2160
# Pizza Hut                   5558      0.6%   7306
# Chipotle Mexican Grill      5509     14.8%   2584
# Sonic Drive-In              4687      4.6%   3526
# KFC                         4546      2.5%   4065
# Olive Garden                4287      5.0%    866
# Applebee's                  4085     -3.0%   1665
# Panda Express               3946     12.0%   2209
# Arby's                      3884      1.9%   3359
# Popeyes Louisiana Kitchen   3812     18.3%   2476
# Little Caesars              3811      2.7%   4237

# %%
# Missing values
top1.isnull().sum()
# Out:
# Rank          0
# Content      13
# Sales         0
# YOY_Sales     0
# Units         0
# dtype: int64

# %%
top2 = top1[~top1['Content'].isnull()]
top2
# Out:
#                 Rank                                            Content  \
# Restaurant
# Chick-fil-A        3  While Popeyes got a lot of the chicken buzz in...
# Dunkin'            8  Dunkin' dropped "Donuts" from its name and rep...
# Pizza Hut         11  The chain moved to replace underperforming din...
# Sonic Drive-In    13  The drive-in chain grew same-store sales for t...
# Olive Garden      15  Olive Garden became the nation's largest casua...
# Panda Express     17  Panda Express has quietly established itself a...
# Little Caesars    20  The third-largest pizza chain's self-service, ...
#
#                 Sales YOY_Sales  Units
# Restaurant
# Chick-fil-A     11320     13.0%   2470
# Dunkin'          9228      5.0%   9630
# Pizza Hut        5558      0.6%   7306
# Sonic Drive-In   4687      4.6%   3526
# Olive Garden     4287      5.0%    866
# Panda Express    3946     12.0%   2209
# Little Caesars   3811      2.7%   4237

# %%
# Grouping
top_grouped = top.groupby('Segment_Category').sum()
top_grouped
# Out:
#                                  Rank  Sales  Units
# Segment_Category
# Asian                             597    608    140
# Asian/Noodle                      521    681    565
# BBQ                              1304   1472   1140
# Bakery Cafe                      1423   1717   1094
# Burger                           1765   2187   2427
# Casual Dining & Asian              52    917    221
# Casual Dining & Italian/Pizza     250   6022   1477
# Casual Dining & Seafood           106   3077    876
# Casual Dining & Sports Bar        176   4973   1645
# Casual Dining & Steak             184   8014   2011
# Casual Dining & Varied Menu       410  15686   4967
# Chicken                          1441   1318    805
# Coffee Cafe                       726    925   1409
# Ethnic                            220    149     93
# Family Casual                     721    807    347
# Family Dining & Family Style      353  11677   7047
# Family Style                     1698   2292   1508
# Fast Casual & Asian/Noodle        103   4479   2666
# Fast Casual & Bakery Cafe          10   5890   2160
# Fast Casual & Burger              286   3318   2182
# Fast Casual & Chicken             212   5216   2988
# Fast Casual & Mexican             125   7159   4044
# Fast Casual & Pizza                93    483    467
# Fast Casual & Sandwich            359   6154   6414
# Fine Dining & Steak                96    461     58
# Frozen Desserts                   714    918   1859
# Healthy                           185    184    102
# Italian/Pizza                    1760   2152    711
# Mexican                          2366   3396   1805
# Pizza                            1288   2585   3114
# Quick Service & Bakery Cafe        87    517    710
# Quick Service & Beverage          259   1552   2573
# Quick Service & Burger            458  79384  39172
# Quick Service & Chicken           202  22619  11271
# Quick Service & Coffee Cafe       155  31889  25763
# Quick Service & Family Casual      39   1746    483
# Quick Service & Frozen Desserts    94   4375   6905
# Quick Service & Mexican            61  12143   7362
# Quick Service & Pizza             396  21316  24027
# Quick Service & Sandwich          224  14965  28171
# Quick Service & Seafood            80    561    540
# Quick Service & Snack             136   1446   1652
# Sandwich                         1051   1807   1973
# Seafood                          1465   1692   1076
# Snack                             837    652   2092
# Sports Bar                       1079   1505    492
# Steak                            1219   2989    531
# Varied Menu                      3989   4610   1384

# %%
top_grouped1 = top.groupby('Segment_Category').mean()
top_grouped1
# Out:
#                                        Rank        Sales        Units
# Segment_Category
# Asian                            199.000000   202.666667    46.666667
# Asian/Noodle                     173.666667   227.000000   188.333333
# BBQ                              186.285714   210.285714   162.857143
# Bakery Cafe                      177.875000   214.625000   136.750000
# Burger                           176.500000   218.700000   242.700000
# Casual Dining & Asian             52.000000   917.000000   221.000000
# Casual Dining & Italian/Pizza     62.500000  1505.500000   369.250000
# Casual Dining & Seafood           53.000000  1538.500000   438.000000
# Casual Dining & Sports Bar        58.666667  1657.666667   548.333333
# Casual Dining & Steak             46.000000  2003.500000   502.750000
# Casual Dining & Varied Menu       45.555556  1742.888889   551.888889
# Chicken                          205.857143   188.285714   115.000000
# Coffee Cafe                      181.500000   231.250000   352.250000
# Ethnic                           220.000000   149.000000    93.000000
# Family Casual                    180.250000   201.750000    86.750000
# Family Dining & Family Style      50.428571  1668.142857  1006.714286
# Family Style                     169.800000   229.200000   150.800000
# Fast Casual & Asian/Noodle        51.500000  2239.500000  1333.000000
# Fast Casual & Bakery Cafe         10.000000  5890.000000  2160.000000
# Fast Casual & Burger              71.500000   829.500000   545.500000
# Fast Casual & Chicken             53.000000  1304.000000   747.000000
# Fast Casual & Mexican             41.666667  2386.333333  1348.000000
# Fast Casual & Pizza               93.000000   483.000000   467.000000
# Fast Casual & Sandwich            59.833333  1025.666667  1069.000000
# Fine Dining & Steak               96.000000   461.000000    58.000000
# Frozen Desserts                  178.500000   229.500000   464.750000
# Healthy                          185.000000   184.000000   102.000000
# Italian/Pizza                    176.000000   215.200000    71.100000
# Mexican                          169.000000   242.571429   128.928571
# Pizza                            143.111111   287.222222   346.000000
# Quick Service & Bakery Cafe       87.000000   517.000000   710.000000
# Quick Service & Beverage          86.333333   517.333333   857.666667
# Quick Service & Burger            35.230769  6106.461538  3013.230769
# Quick Service & Chicken           33.666667  3769.833333  1878.500000
# Quick Service & Coffee Cafe       38.750000  7972.250000  6440.750000
# Quick Service & Family Casual     39.000000  1746.000000   483.000000
# Quick Service & Frozen Desserts   47.000000  2187.500000  3452.500000
# Quick Service & Mexican           30.500000  6071.500000  3681.000000
# Quick Service & Pizza             49.500000  2664.500000  3003.375000
# Quick Service & Sandwich          56.000000  3741.250000  7042.750000
# Quick Service & Seafood           80.000000   561.000000   540.000000
# Quick Service & Snack             68.000000   723.000000   826.000000
# Sandwich                         150.142857   258.142857   281.857143
# Seafood                          183.125000   211.500000   134.500000
# Snack                            209.250000   163.000000   523.000000
# Sports Bar                       179.833333   250.833333    82.000000
# Steak                            135.444444   332.111111    59.000000
# Varied Menu                      181.318182   209.545455    62.909091

# %%
# Import csv file
pd.read_csv('D:/CSV/Independence100.csv')
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# 1     Orlando     Fla.      820819.0
# 2   Washington    D.C.      892830.0
# 3     New York    N.Y.      198500.0
# 4     New York    N.Y.      403000.0
# ..         ...     ...           ...
# 95    La Jolla  Calif.      250000.0
# 96    New York    N.Y.       87070.0
# 97  Washington    D.C.      226226.0
# 98    New York    N.Y.      171825.0
# 99   Las Vegas    Nev.      208276.0
#
# [100 rows x 7 columns]

# %%
# Set up file name
ind = pd.read_csv('D:/CSV/Independence100.csv')

# %%
# Use head command
ind.head(20)
# Out:
#     Rank                               Restaurant       Sales  Average Check  \
# 0      1                 Carmine's (Times Square)  39080335.0             40
# 1      2                    The Boathouse Orlando  35218364.0             43
# 2      3                         Old Ebbitt Grill  29104017.0             33
# 3      4      LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5                 Bryant Park Grill & Cafe  26900000.0             62
# 5      6                 Gibsons Bar & Steakhouse  25409952.0             80
# 6      7           Top of the World at the STRAT   25233543.0            103
# 7      8                              Maple & Ash  24837595.0             99
# 8      9                                Balthazar  24547800.0             87
# 9     10                        Smith & Wollensky  24501000.0            107
# 10    11                               Angus Barn  24268160.0             75
# 11    12                                Prime 112  23800000.0            135
# 12    13  Joe's Seafood, Prime Steak & Stone Crab  23660000.0             86
# 13    14                  Junior's (Times Square)  23640652.0             23
# 14    15                             The Hamilton  23138062.0             33
# 15    16  Joe's Seafood, Prime Steak & Stone Crab  22981600.0             91
# 16    17  Joe's Seafood, Prime Steak & Stone Crab  22859400.0             81
# 17    18                           Gibsons Italia  22749232.0            108
# 18    19                                   Komodo  22500000.0             98
# 19    20                                 Buddakan  22395577.0             67
#
#            City State  Meals Served
# 0      New York  N.Y.      469803.0
# 1      Orlando   Fla.      820819.0
# 2    Washington  D.C.      892830.0
# 3      New York  N.Y.      198500.0
# 4      New York  N.Y.      403000.0
# 5       Chicago  Ill.      348567.0
# 6     Las Vegas  Nev.      246054.0
# 7       Chicago  Ill.      210832.0
# 8      New York  N.Y.      519000.0
# 9      New York  N.Y.      257364.0
# 10      Raleigh  N.C.      315000.0
# 11  Miami Beach  Fla.      206000.0
# 12   Washington  D.C.      277850.0
# 13     New York  N.Y.      914500.0
# 14   Washington  D.C.      700861.0
# 15      Chicago  Ill.      252500.0
# 16    Las Vegas  Nev.      286000.0
# 17      Chicago  Ill.      252962.0
# 18        Miami  Fla.      265000.0
# 19     New York  N.Y.      221059.0

# %%
# Use info command
ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           100 non-null    int64
#  1   Restaurant     100 non-null    object
#  2   Sales          100 non-null    float64
#  3   Average Check  100 non-null    int64
#  4   City           100 non-null    object
#  5   State          100 non-null    object
#  6   Meals Served   100 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.4+ KB

# %%
# Slicing
ind.iloc[0:20, 0:6]
ind
# Out:
#                                          Rank       Sales  Average Check  \
# Restaurant
# Carmine's (Times Square)                    1  39080335.0             40
# The Boathouse Orlando                       2  35218364.0             43
# Old Ebbitt Grill                            3  29104017.0             33
# LAVO Italian Restaurant & Nightclub         4  26916180.0             90
# Bryant Park Grill & Cafe                    5  26900000.0             62
# Gibsons Bar & Steakhouse                    6  25409952.0             80
# Top of the World at the STRAT               7  25233543.0            103
# Maple & Ash                                 8  24837595.0             99
# Balthazar                                   9  24547800.0             87
# Smith & Wollensky                          10  24501000.0            107
# Angus Barn                                 11  24268160.0             75
# Prime 112                                  12  23800000.0            135
# Joe's Seafood, Prime Steak & Stone Crab    13  23660000.0             86
# Junior's (Times Square)                    14  23640652.0             23
# The Hamilton                               15  23138062.0             33
# Joe's Seafood, Prime Steak & Stone Crab    16  22981600.0             91
# Joe's Seafood, Prime Steak & Stone Crab    17  22859400.0             81
# Gibsons Italia                             18  22749232.0            108
# Komodo                                     19  22500000.0             98
# Buddakan                                   20  22395577.0             67
#
#                                                 City State
# Restaurant
# Carmine's (Times Square)                    New York  N.Y.
# The Boathouse Orlando                       Orlando   Fla.
# Old Ebbitt Grill                          Washington  D.C.
# LAVO Italian Restaurant & Nightclub         New York  N.Y.
# Bryant Park Grill & Cafe                    New York  N.Y.
# Gibsons Bar & Steakhouse                     Chicago  Ill.
# Top of the World at the STRAT              Las Vegas  Nev.
# Maple & Ash                                  Chicago  Ill.
# Balthazar                                   New York  N.Y.
# Smith & Wollensky                           New York  N.Y.
# Angus Barn                                   Raleigh  N.C.
# Prime 112                                Miami Beach  Fla.
# Joe's Seafood, Prime Steak & Stone Crab   Washington  D.C.
# Junior's (Times Square)                     New York  N.Y.
# The Hamilton                              Washington  D.C.
# Joe's Seafood, Prime Steak & Stone Crab      Chicago  Ill.
# Joe's Seafood, Prime Steak & Stone Crab    Las Vegas  Nev.
# Gibsons Italia                               Chicago  Ill.
# Komodo                                         Miami  Fla.
# Buddakan                                    New York  N.Y.

# %%
ind['Sales'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Restaurant'>
